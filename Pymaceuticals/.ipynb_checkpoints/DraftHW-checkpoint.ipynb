# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# ## Dependencies and starter code

# %%
# %matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# %%
# Combine the data into a single dataset

# %%
df = pd.merge(mouse_metadata, study_results, how="left", on=["Mouse ID", "Mouse ID"])

# %%
df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %% [markdown]
# ## Summary statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# %%
# create a subset for grouping by

# %%
tumor_volume=df[["Drug Regimen","Tumor Volume (mm3)"]]

# %%
#getting Describe() statistics

# %%
tumor_volume_stat=tumor_volume.groupby("Drug Regimen").describe()

# %%
#getting Standard Error (SEM) stats

# %%
tumor_volume_sem=tumor_volume.groupby("Drug Regimen").sem()

# %%
tumor_volume_stat
# Out:
#              Tumor Volume (mm3)                                             \
#                           count       mean       std        min        25%
# Drug Regimen
# Capomulin                 230.0  40.675741  4.994774  23.343598  37.685933
# Ceftamin                  178.0  52.591172  6.268188  45.000000  47.208427
# Infubinol                 178.0  52.884795  6.567243  36.321346  47.312353
# Ketapril                  188.0  55.235638  8.279709  45.000000  48.232987
# Naftisol                  186.0  54.331565  8.134708  45.000000  47.285874
# Placebo                   181.0  54.033581  7.821003  45.000000  47.459053
# Propriva                  161.0  52.322552  6.507770  45.000000  47.081086
# Ramicane                  228.0  40.216745  4.846308  22.050126  36.674635
# Stelasyn                  181.0  54.233149  7.710419  45.000000  48.047139
# Zoniferol                 182.0  53.236507  6.966589  45.000000  47.337876
#
#
#                     50%        75%        max
# Drug Regimen
# Capomulin     41.557809  45.000000  48.158209
# Ceftamin      51.776157  56.801438  68.923185
# Infubinol     51.820584  57.314444  72.226731
# Ketapril      53.698743  60.870951  78.567014
# Naftisol      52.509285  59.963034  76.668817
# Placebo       52.288934  59.916934  73.212939
# Propriva      50.854632  56.184664  72.455421
# Ramicane      40.673236  45.000000  47.622816
# Stelasyn      52.431737  58.719297  75.123690
# Zoniferol     51.818479  57.954259  73.324432

# %%
#Renaming column in SEM df

# %%
tumor_volume_sem=tumor_volume_sem.rename({"Tumor Volume (mm3)":"SEM"},axis=1)

# %%
tumor_volume_sem
# Out:
#                    SEM
# Drug Regimen
# Capomulin     0.329346
# Ceftamin      0.469821
# Infubinol     0.492236
# Ketapril      0.603860
# Naftisol      0.596466
# Placebo       0.581331
# Propriva      0.512884
# Ramicane      0.320955
# Stelasyn      0.573111
# Zoniferol     0.516398

# %%
#merging Describe and SEM dfs

# %%
tumor_volume_final=pd.merge(tumor_volume_stat,tumor_volume_sem,how="left",on=["Drug Regimen"])

# %%
#renaming columns in resulting df

# %%
tumor_volume_final.columns=['Count','Mean','STD','MIN','25%','Meidan','75%','MAX','SEM']

# %%
tumor_volume_final
# Out:
#               Count       Mean       STD        MIN        25%     Meidan  \
# Drug Regimen
# Capomulin     230.0  40.675741  4.994774  23.343598  37.685933  41.557809
# Ceftamin      178.0  52.591172  6.268188  45.000000  47.208427  51.776157
# Infubinol     178.0  52.884795  6.567243  36.321346  47.312353  51.820584
# Ketapril      188.0  55.235638  8.279709  45.000000  48.232987  53.698743
# Naftisol      186.0  54.331565  8.134708  45.000000  47.285874  52.509285
# Placebo       181.0  54.033581  7.821003  45.000000  47.459053  52.288934
# Propriva      161.0  52.322552  6.507770  45.000000  47.081086  50.854632
# Ramicane      228.0  40.216745  4.846308  22.050126  36.674635  40.673236
# Stelasyn      181.0  54.233149  7.710419  45.000000  48.047139  52.431737
# Zoniferol     182.0  53.236507  6.966589  45.000000  47.337876  51.818479
#
#                     75%        MAX       SEM
# Drug Regimen
# Capomulin     45.000000  48.158209  0.329346
# Ceftamin      56.801438  68.923185  0.469821
# Infubinol     57.314444  72.226731  0.492236
# Ketapril      60.870951  78.567014  0.603860
# Naftisol      59.963034  76.668817  0.596466
# Placebo       59.916934  73.212939  0.581331
# Propriva      56.184664  72.455421  0.512884
# Ramicane      45.000000  47.622816  0.320955
# Stelasyn      58.719297  75.123690  0.573111
# Zoniferol     57.954259  73.324432  0.516398

# %% [markdown]
# ## Bar plots

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas

# %%
data_point_df=tumor_volume_final[["Count"]]
#tumor_list

# %%
data_point_fin=data_point_df.reset_index()

# %%
data_point_fin.columns=['Treatment','Count']
data_point_fin
# Out:
#    Treatment  Count
# 0  Capomulin  230.0
# 1   Ceftamin  178.0
# 2  Infubinol  178.0
# 3   Ketapril  188.0
# 4   Naftisol  186.0
# 5    Placebo  181.0
# 6   Propriva  161.0
# 7   Ramicane  228.0
# 8   Stelasyn  181.0
# 9  Zoniferol  182.0

# %%
data_point_fin.plot(kind="bar",figsize=(5,3))

#set title
plt.title("Data points per treatment")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="498.88890210493145">

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pyplot

# %%
#set x axis and Tick locations
x_axis=np.arange(len(data_point_fin))
tick_locations=[x for x in x_axis]

# %%
#setting plot
plt.figure(figsize=(5,3))
plt.bar(x_axis,data_point_fin["Count"],color='r',alpha=0.75,width=0.7,align="center")
plt.xticks(tick_locations,data_point_fin["Treatment"],rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="498.88890210493145">
# ([<matplotlib.axis.XTick at 0x170863c5848>,
#   <matplotlib.axis.XTick at 0x170863bde88>,
#   <matplotlib.axis.XTick at 0x1708603a148>,
#   <matplotlib.axis.XTick at 0x170877f8488>,
#   <matplotlib.axis.XTick at 0x17087b2dcc8>,
#   <matplotlib.axis.XTick at 0x17084c88ec8>,
#   <matplotlib.axis.XTick at 0x17083ba6908>,
#   <matplotlib.axis.XTick at 0x17087b15b88>,
#   <matplotlib.axis.XTick at 0x17087b15188>,
#   <matplotlib.axis.XTick at 0x17087b86348>],
#  <a list of 10 Text xticklabel objects>)

# %%
#setting X and y limits
plt.xlim(-.075,len(x_axis))
plt.ylim(0,max(data_point_fin['Count']))
# Out:
# (0, 230.0)

# %%
#set title and labels
plt.title("Data points for each treatment")
plt.xlabel("Treatment")
plt.ylabel("Number of data points")
plt.tight_layout()

# %% [markdown]
# ## Pie plots

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
df_pie=df[["Drug Regimen","Sex"]]
df_pie
# Out:
#      Drug Regimen   Sex
# 0        Ramicane  Male
# 1        Ramicane  Male
# 2        Ramicane  Male
# 3        Ramicane  Male
# 4        Ramicane  Male
# ...           ...   ...
# 1888     Naftisol  Male
# 1889     Naftisol  Male
# 1890     Naftisol  Male
# 1891     Naftisol  Male
# 1892     Naftisol  Male
#
# [1893 rows x 2 columns]

# %%
df_pie_group=df_pie.groupby("Sex").count()
df_pie_group.head()
# Out:
#         Drug Regimen
# Sex
# Female           935
# Male             958

# %%
df_pie_group.plot(kind="pie",subplots=True,figsize=(5,5))
# Out:
# <img src="data:image/png;base64,..." width="498.88890210493145">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017083BD1E88>],
#       dtype=object)

# %%
df_pie_group
v=df_pie_group.reset_index()

# %%
#df_pie_group.tolist()

# %%
sex=v["Sex"].tolist()
sex
# Out:
# ['Female', 'Male']

# %%
count=v["Drug Regimen"].tolist()
count
# Out:
# [935, 958]

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %%
plt.pie(count,labels=sex)
# Out:
# ([<matplotlib.patches.Wedge at 0x17087aba608>,
#   <matplotlib.patches.Wedge at 0x17087ab2848>],
#  [Text(0.02099250347258556, 1.0997996703027118, 'Female'),
#   Text(-0.020992503472586185, -1.0997996703027118, 'Male')])

# %% [markdown]
# ## Quartiles, outliers and boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. Calculate the IQR and quantitatively determine if there are any potential outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and scatter plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
